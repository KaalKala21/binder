# %%
# !curl ifconfig.me

# %%
# !apt-get update

# %%
# !apt install chromium-chromedriver -y

# %%
# !pip install selenium

# %%
# !git clone https://KaalKala21:Mindstady1998@github.com/KaalKala21/test21.git

# %%
cd test21

# %%
import time
time.sleep(5400)

# %%
# !python revive1.py

# %%
# !curl ifconfig.me
